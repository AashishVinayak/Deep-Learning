# %%
import pandas as pd
import nltk
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.models import Sequential
from keras.layers import Dense,GRU,Dropout
from keras.utils import to_categorical
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import keras
import tensorflow as tf
config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 6} ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
# importing data
data = pd.DataFrame(pd.read_csv("https://raw.githubusercontent.com/aashishksahu/Deep-Learning/master/Text%20Classification/data.csv")).dropna()
data.reindex(np.random.permutation(data.index))
print("dataset length: ",len(data))
# Out:
# dataset length:  19662

# %%
### preprocessing
# importing stopwords
from nltk.corpus import stopwords
stopwords = list(set(stopwords.words("english")))

# convert to list
review = list(data['Review Text'])

for i in range(len(review)):
    # remove unnecessary characters
    review[i] = re.findall(r'[a-zA-Z]\w+', review[i])
    # remove stopwords
    review[i] = [word for word in review[i] if word not in stopwords]
    # join words to form text
    review[i] = ' '.join(review[i])

# target 
recommendation = np.asarray(data['Recommended IND'])

# %%
# creating TF-IDF matrix
vectorizer = TfidfVectorizer()
vectorizer.fit(review)

# create tf-idf scores
tfidf = vectorizer.transform(review)
tfidf = tfidf.toarray()
print(tfidf.shape)
# train-test split
x_train = tfidf[0:15000]
x_train = x_train.reshape(15000,13011 , 1)
y_train = recommendation[0:15000]

x_test = tfidf[15000:len(review)]
x_test = x_test.reshape(len(x_test), 13011, 1)
y_test = recommendation[15000:len(recommendation)]

# free memory
del(review)
del(recommendation)
del(data)
del(stopwords)
# Out:
# (19662, 13011)

# %%
model = Sequential()
model.add(GRU(8, return_sequences=True,input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(GRU(8))
model.add(Dense(1, activation='softmax'))
model.compile(loss = "binary_crossentropy", optimizer="adam",  metrics = ['accuracy'])
model.fit(x_train, y_train.reshape(len(y_train),1), epochs=1, batch_size=512)
# Out:
# Epoch 1/1
# 15000/15000 [==============================] - 1791s 119ms/step - loss: 2.8707 - acc: 0.8199

# %%
# evaluation
model.evaluate(x_test, y_test.reshape(len(y_test),1), batch_size=512)
# Out:
# 4662/4662 [==============================] - 133s 28ms/step
# [2.9887696419187697, 0.812526812859228]

# %% [markdown]
# #### I tried several approaches and designed different structures of the models but the accuracy stays the same, this is due to:
# #### 1. Lack of data
# #### 2. Lack of computation power
# #### 3. And it could be some other factors too....
